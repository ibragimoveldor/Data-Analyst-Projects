# %% [markdown]
# # Project: Investigate a Dataset (TMDb Movie Data)
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# This data set contains information
# about 10,000 movies collected from
# The Movie Database (TMDb),
# including user ratings and revenue.  The analysis will be applited to this dataset according to importancy of the data. The main data analysis proccesses that will be used are Data cleaning, Data wrangling and investigating data and giving some conclusion at the end. The analysis include following variables:
#
#
#     - popularity
#     - budget
#     - revenue
#     - original_title
#     - keywords
#     - genres
#     - vote_count
#     - release_year
#
#
# ### Questions:
#
#     1. What are th Top 10 most high budget movies
#     2. What keywords word is the most popular?
#     3. What genres with the highest release?
#     4. What are the most voted movies?
#     5. Relationship between popularity vs budget ? poularity vs revenue?
#     6. What is a Budget and revenue change per year?
#     7. How the number of released movies are changed per-year?

# %%
#import packages for data analysis and plotting eand etc.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
#
#
# ### General Properties

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.
df = pd.read_csv('Data/tmdb-movies.csv')

# check general info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# release_year            10866 non-null int64
# budget_adj              10866 non-null float64
# revenue_adj             10866 non-null float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %%
# shape of the data 
df.shape
# Out:
# (10866, 21)

# %%
# let's see first five rows of the data
df.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline      ...       \
# 0              The park is open.      ...
# 1             What a Lovely Day.      ...
# 2     One Choice Can Destroy You      ...
# 3  Every generation has a story.      ...
# 4            Vengeance Hits Home      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
# check lat rows of the data
df.tail(2)
# Out:
#           id    imdb_id  popularity  budget  revenue  \
# 10864  21449  tt0061177    0.064317       0        0
# 10865  22293  tt0060666    0.035919   19000        0
#
#                  original_title  \
# 10864    What's Up, Tiger Lily?
# 10865  Manos: The Hands of Fate
#
#                                                     cast homepage  \
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...      NaN
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...      NaN
#
#                director                                       tagline  \
# 10864       Woody Allen                     WOODY ALLEN STRIKES BACK!
# 10865  Harold P. Warren  It's Shocking! It's Beyond Your Imagination!
#
#           ...                                                overview runtime  \
# 10864     ...       In comic Woody Allen's film debut, he took the...      80
# 10865     ...       A family gets lost on the road and stumbles up...      74
#
#               genres     production_companies release_date vote_count  \
# 10864  Action|Comedy  Benedict Pictures Corp.      11/2/66         22
# 10865         Horror                Norm-Iris     11/15/66         15
#
#        vote_average  release_year     budget_adj  revenue_adj
# 10864           5.4          1966       0.000000          0.0
# 10865           1.5          1966  127642.279154          0.0
#
# [2 rows x 21 columns]

# %%
# Summary statistics for columns
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# std      575.619058      0.935142     12.812941  3.430616e+07  1.446325e+08
# min       10.000000      1.500000   1960.000000  0.000000e+00  0.000000e+00
# 25%       17.000000      5.400000   1995.000000  0.000000e+00  0.000000e+00
# 50%       38.000000      6.000000   2006.000000  0.000000e+00  0.000000e+00
# 75%      145.750000      6.600000   2011.000000  2.085325e+07  3.369710e+07
# max     9767.000000      9.200000   2015.000000  4.250000e+08  2.827124e+09

# %%
# The number of unique values for each column 
df.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# #### 1. Check for Nan values in the data

# %%
# summing up all nan values in the data by using isnull() command and sum()
null_values = df.isnull().sum()
null_values
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# As we can see from the output. Most columns wit Nan values are 'homepage', 'tagline', 'keywords' and
# 'production companies'. Since the columns are mostly related each othe it is hard to get rid of all nan values
# for the whole data, instead we did removed Nan values accordingly.

# %% [markdown]
# #### 2. Check for duplicates

# %%
# check for duplicate values in the columns of data
duplicated = df.duplicated().sum()
duplicated
# Out:
# 1

# %% [markdown]
# > It can be clear that the there is only one duplicated data.

# %%
# remove duplicates from the data
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### 3.Change the datformat for 'release_date' column to datatime format

# %%
# the datformate for release_date columns is in the string format
# it will be changed to datetime format
df['release_date'] = pd.to_datetime(df['release_date'])
df['release_date'].head(3)
# Out:
# 0   2015-06-09
# 1   2015-05-13
# 2   2015-03-18
# Name: release_date, dtype: datetime64[ns]

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %% [markdown]
# ### Research question: 1. Top 10 most high budget movies

# %%
#Top 10 movies by its budget

#to discover this we need movie title and budget columns from the database
top10_movies = df[['budget','original_title']]

#budget values are sorted in ascending order and top 10 movies are selected 
top10 = top10_movies.sort_values('budget', ascending = False)[0:10]
# set the figure size
plt.figure(figsize=(8,6))
#plot as a bar chart
plt.bar(top10['original_title'], top10['budget']);
# setting x and y labels of the chart
plt.ylabel('Budget ($)')
plt.xlabel('Movies')
# rotate the movie names for better to avoid mix of names on the chart
plt.xticks(rotation=90)
plt.title('Top 10 expensive movies by budget')
plt.show()

# %% [markdown]
# Short conclusion: Overall the plot shows that the average budget for all movies is avove than 2.5 billion dollar. The highest budet movies was "The Warrior's Way.

# %% [markdown]
# ### Research Question 2:  What keyword word is the most popular?

# %%
# extract the keyword column from the data 
kword = df['keywords']
kword.head(5)
# Out:
# 0    monster|dna|tyrannosaurus rex|velociraptor|island
# 1     future|chase|post-apocalyptic|dystopia|australia
# 2    based on novel|revolution|dystopia|sequel|dyst...
# 3                android|spaceship|jedi|space opera|3d
# 4                  car race|speed|revenge|suspense|car
# Name: keywords, dtype: object

# %% [markdown]
# >As we can see keywords row include many different words with separated with "|"
# Since our plan is to count each word frequency in search we need to count them one bye one. Thus I created simple function below for counting occurrences for each word

# %%
a = []
for i in range(len(kword)):
    lis = str(kword[i]).split('|')
    print(lis)
    for j in range(len(lis)):
        a.append(lis[j])
print(a)
# Out:
# ['monster', 'dna', 'tyrannosaurus rex', 'velociraptor', 'island']
# ['future', 'chase', 'post-apocalyptic', 'dystopia', 'australia']
# ['based on novel', 'revolution', 'dystopia', 'sequel', 'dystopic future']
# ['android', 'spaceship', 'jedi', 'space opera', '3d']
# ['car race', 'speed', 'revenge', 'suspense', 'car']
# ['father-son relationship', 'rape', 'based on novel', 'mountains', 'winter']
# ['saving the world', 'artificial intelligence', 'cyborg', 'killer robot', 'future']
# ['based on novel', 'mars', 'nasa', 'isolation', 'botanist']
# ['assistant', 'aftercreditsstinger', 'duringcreditsstinger', 'evil mastermind', 'minions']
# ['dream', 'cartoon', 'imaginary friend', 'animation', 'kid']
# ['spy', 'based on novel', 'secret agent', 'sequel', 'james bond']
# ['jupiter', 'space', 'woman director', '3d', 'interspecies romance']
# ['dancing', 'artificial intelligence', 'helicopter', 'distrust', 'isolation']
# ['video game', 'nerd', 'alien attack', '3d', 'pixels']
# ['marvel comic', 'comic', 'sequel', 'superhero', 'vision']
# ['bounty hunter', 'wyoming', 'mountains', 'hangman', 'voice over narration']
# ['revenge', 'murder', 'on the run', 'fugitive', 'framed']
# ['marvel comic', 'superhero', 'aftercreditsstinger', 'duringcreditsstinger', 'marvel cinematic universe']
# ['cinderella', 'magic', 'fairy tale', 'princess', 'shoe']
# ['revolution', 'strong woman', 'dystopia', 'game of death', '3d']
# ['inventor', 'apocalypse', 'destiny', 'imax', 'dreamer']
# ['sport']
# ['california', 'earthquake', 'catastrophe', 'disaster film', '3d']
# ['based on novel', 'billionaire', 'bdsm', 'woman director', 'erotic movie']
# ['bank', 'fraud', 'biography', 'wall street', 'finances']
# ['spy', 'sequel', 'mission']
# ['sperm bank', 'sequel', 'buddy', 'courthouse', 'teddy bear']
# ['spy', 'great britain', 'secret organization', 'secret agent', 'marvel comic']
# ['child abuse', 'journalism', 'judge', 'florida', 'boston']
# ['based on novel', 'resistance', 'maze', 'post-apocalyptic', 'dystopia']
# ['london', 'detective', 'sherlock holmes']
# ['artificial intelligence', 'android', 'robot', 'near future', 'robot cop']
# ['music', 'sequel', 'singer', 'male female relationship', 'audition']
# ['spy', 'cia', 'cold war', 'pilot', 'lawyer']
# ['based on novel', 'magic', 'fantasy', 'family', '3d']
# ['based on novel', 'carpet', 'isolation', 'imprisonment', 'grandparents']
# ['thriller', 'serial killer', 'psychic', 'fbi agent', 'intrigue']
# ['tyrannosaurus rex', 'friends', 'animation', 'alternate history', 'dinosaur']
# ['hitman', 'revenge', 'murder', 'on the run', 'mobster']
# ['love triangle', 'based on novel', 'homesickness', 'vororte', 'ship']
# ['brother brother relationship', 'aids', 'police brutality', 'hip-hop', 'wife husband relationship']
# ['new york', 'witch', 'uprising', 'witch hunter']
# ['biography', 'computer', 'based on true story', 'father daughter relationship', 'apple computer']
# ['spy', 'cold war', 'remake', 'based on tv series', 'buddy cop']
# ['san francisco', 'immortality', 'love', 'forever']
# ['female nudity', 'cyborg', 'nudity', 'murder', 'gore']
# ['friendship', 'spaceship', 'space', 'alien', 'alien invasion']
# ['friendship', 'high school', 'teen', 'classmate', 'based on young adult book']
# ['gambling', 'bodyguard', 'remake']
# ['dystopia']
# ['gay', 'new york', 'female nudity', 'chicago', 'sex']
# ['intern', 'woman director']
# ['mountains', 'snow storm', 'hiking', 'snow', 'death']
# ['biography']
# ['undercover', 'undercover agent', 'extreme sports', 'fbi agent', '3d']
# ['london', 'cook', 'restaurant', 'diva', 'career']
# ['lie', 'immortality', 'terminal illness', 'laboratory', 'cancer']
# ['based on novel', 'painting', 'debt', 'art dealer', 'stolen painting']
# ['paris', 'denmark', 'copenhagen', 'artist', 'art']
# ['terrorist', 'technology', 'anti hero', 'hacker', 'computer virus']
# ['mexico', 'cia', 'smoking', 'texas', 'fbi']
# ['teleportation', 'transformation', 'telekinesis', 'portal', 'marvel comic']
# ['witch', 'new england', '17th century']
# ['spy', 'cia', 'undercover', 'arms dealer', 'disaster']
# ['seduction', 'con man', 'femme fatale', 'deception', 'con artist']
# ['assassin', 'secret identity', 'intelligence', 'hitman', 'execution']
# ['suicide', 'ocean', 'sea', 'hunger', 'shipwreck']
# ["new year's eve", 'fire', 'showdown', 'terrorist', 'embassy']
# ['underdog', 'sport', 'spin off', 'underground fighting', 'motivational speaker']
# ['alcohol', 'one-night stand']
# ['terrorist', 'drone', 'u.s. military', 'air force base', 'combat drone']
# ['biography', 'based on true story', 'gangster', 'twins']
# ['desert', 'hunting']
# ['flying', 'magic', 'fairy tale', 'peter pan', 'mermaid']
# ['sword', 'magic', 'sorcery', 'necromancer', 'woman director']
# ['tattoo', 'high school', 'leukemia', 'friends', 'parody']
# ['based on comic strip', 'family', '3d', 'charlie brown', 'snoopy']
# ['american football', 'biography', 'professional sports', 'sports injury', 'nfl']
# ['male friendship', 'new york city', 'drug', 'christmas eve', 'childhood friend']
# ['female nudity', 'sex', 'disc jockey', 'infidelity', 'rain']
# ['based on novel', 'art student', 'cowboys', 'injury', 'bull riding']
# ['transylvania', 'hotel', 'witch', 'technology', 'magic']
# ['big family', 'family relationships', 'family', 'woman director', 'christmas']
# ['1970s', 'skyscraper', 'based on true story', 'tightrope', 'planning']
# ['chinese mafia', 'parkour', 'new york city', 'loan shark', 'young adult']
# ['route 66', 'grand canyon', 'cow', 'vacation', 'road trip']
# ['poltergeist', 'haunted house', 'remake', 'duringcreditsstinger']
# ['post-apocalyptic', 'dystopia', 'zombies']
# ['illustrator', 'sex scene', 'near future', 'infected', 'emotions']
# ['murder', 'serial killer', 'military', 'chili', 'soviet union']
# ['detective', 'stalker', 'gift', 'bully', 'psychological thriller']
# ['daddys home']
# ['sword', 'magic', 'sorcery', 'necromancer']
# ['artificial intelligence', 'android', 'self-awareness', 'mercenary', 'virtual reality']
# ['philosophy', 'utopia', 'airplane', 'adventure', 'dystopia']
# ['chipmunk', 'cgi', 'talking animal', 'aftercreditsstinger', 'duringcreditsstinger']
# ['based on novel', 'australia', 'dressmaker', 'hometown', 'woman director']
# ['high school', 'teenager', 'popularity', 'high school senior', 'teen comedy']
# ['haunted house', 'sequel', 'twins']
# ['shopping mall', 'las vegas nevada', 'security guard']
# ['sister sister relationship', 'birthday', 'song', 'birthday party', 'flu']
# ['skyscraper', 'high rise']
# ['male nudity', 'female nudity', 'sex', 'adultery', 'infidelity']
# ['corruption', 'terrorist', 'explosive', 'police', 'kidnapping']
# ['friendship', 'hollywood', 'movie star', 'entourage']
# ['male friendship', 'impersonator', 'wedding', 'lying', 'best man']
# ['female nudity', 'shotgun', 'nudity', 'strip club', 'party']
# ['rap', 'pennsylvania', 'brother sister relationship', 'farm', 'grandparents']
# ['boston', 'based on true story', 'organized crime']
# ['casino', 'robbery', 'bus hijacking', 'heist']
# ['fire', 'winter', 'santa claus', 'snow storm', 'christmas tree']
# ['prison', 'based on novel', 'brother sister relationship', 'satanism', 'witness']
# ['coup', 'american', 'family', 'foreign']
# ['california', 'hip-hop', 'harvard university', 'geek', 'coming of age']
# ['memory loss', 'stoner', 'black ops']
# ['nazis', 'art', 'stolen painting']
# ['magic', 'fantasy', 'steampunk', 'dragon']
# ['sister sister relationship', 'childhood home']
# ['time travel', 'time machine', 'teenager', 'found footage']
# ['london', 'alien', 'teacher', 'talking animal', 'super powers']
# ['transporter', 'sequel', 'suspense', 'car', 'bank heist']
# ['haunted house', 'mining', 'murder', 'spitting blood', 'gothic']
# ['assassin', 'mob boss']
# ['male friendship', 'strip club', 'road trip', 'strip tease', 'strip']
# ['terror', 'supernatural', 'sequel', 'demon', 'found footage']
# ['fire', 'bounty hunter', 'shotgun', 'horseback riding', 'horse']
# ['screenwriter', 'communist', 'biography', 'film history', 'hollywood']
# ['fbi', 'missing child']
# ['comedy']
# ['ocean', 'sea', 'star', 'water', 'comedy']
# ['nan']
# ['afghanistan', 'war', 'based on true story', 'rescue', 'betrayal']
# ['countryside', 'sheep', 'based on tv series', 'memory loss', 'hospital']
# ['usa', 'brother brother relationship', 'father-son relationship', 'car accident', 'death of mother']
# ['road movie']
# ['assassin', 'hitman']
# ['computer', 'bullying', 'revenge', 'internet', 'violence']
# ['texas', 'prisoner', 'cop', 'drug cartel', 'on the run']
# ['sequel']
# ['love triangle', 'based on novel', 'jealousy', 'radiation', 'tractor']
# ['magic', 'wall', 'druid', 'knight', 'dragon']
# ['based on novel', 'biography', 'based on true story']
# ['london', 'frankenstein', 'human experiment', 'reanimated corpse', "frankenstein's monster"]
# ['eagle', 'learning to fly', "eagle's feather", 'father son conflict', "bird's nest"]
# ['sex', 'depression', 'existentialism']
# ['poison', 'prisoner', 'murder', 'rifle', 'gore']
# ['investigation', 'memory loss']
# ['chess', 'cold war', 'russia', 'biography', 'victory']
# ['england', 'indian', 'mathematician', 'biography', 'cambridge']
# ['nan']
# ['1970s', 'teenage girl', 'older man younger woman relationship', 'based on graphic novel', 'teenage sexuality']
# ['halloween', 'police', 'revenge', 'burned alive', 'children']
# ['violence', 'psychiatrist', 'dark', 'evil', 'woman director']
# ['loyalty', 'emperor', 'castle', 'sword fight', 'revenge']
# ['nan']
# ['nan']
# ['middle east', 'persia', 'adventurer']
# ['homophobia', 'rock star', 'aging', 'family relationships', 'divorce']
# ['female friendship', 'music', 'friendship', 'love', 'cancer']
# ['video game', 'martial arts', 'kung fu', 'hacker', 'nazis']
# ['nan']
# ['italy', 'fish', 'rock star', 'vacation', 'rock concert']
# ['marriage', 'middle age']
# ['prison', 'training', 'framed', 'embezzlement']
# ['nan']
# ['wild west']
# ['assassin', 'dark comedy']
# ['mining', 'chile', 'based on true story', 'survival', 'woman director']
# ['london', 'biography', 'feminist', 'period drama', 'woman director']
# ['secret', 'marriage']
# ['dj']
# ['assassin', 'high school']
# ['scotland', 'shakespeare', 'medieval']
# ['terrorist', 'kidnapping', 'ex cia agent', 'rescue operation']
# ['woman director']
# ['fairy tale', 'villain', 'musical', 'teen movie', 'teenager']
# ['widow', 'biography', 'writer', 'folk singer']
# ['sheep', 'rural setting', 'housekeeper']
# ['nan']
# ["old people's home"]
# ['nan']
# ['dc comics', 'based on comic book', 'super powers', 'lego']
# ['nan']
# ['hawaii', 'military']
# ['one-night stand', 'romantic comedy', 'accidental love']
# ['video game', 'based on novel', 'space war', 'animation', 'halo']
# ['political campaign', 'south america']
# ['female nudity', 'rape', 'fire', 'dancer', 'based on novel']
# ['psychological thriller', 'psycho thriller', 'woman director', 'reunited friends', 'dinner party']
# ['nan']
# ['bear', 'open season', 'elliot', 'boog']
# ['sheriff', 'colorado', 'murder', 'suspense', 'shootout']
# ['nan']
# ['sex', 'cheating', 'love', 'male female relationship', 'woman director']
# ['nan']
# ['jazz', 'drug addiction', 'overdose', 'biography', 'addiction']
# ['period piece', 'social status', 'extramarital affair', 'woman director']
# ['baby', 'fairy tale', 'tree', 'transformation', 'mill']
# ['barbie', 'princess', 'super powers']
# ['england', 'fire', 'conductor', 'chase', 'transformation']
# ['new jersey', 'equality', 'lesbian couple', 'cancer']
# ['bowling', 'blind date', 'party', 'mistaken identity', 'wedding anniversary']
# ['paris', 'sex', 'sexuality', 'cocaine', 'nudity']
# ['document', 'biography', 'one word title', 'tv reporter', 'directorial debut']
# ['date', 'prison', 'nurse', 'rape', 'flirting']
# ['rock star', 'middle age']
# ['jealousy', 'ex-boyfriend', 'afghanistan', 'record producer', 'last chance']
# ['widow', 'mental breakdown', 'family']
# ['dating', 'middle age']
# ['exorcism', 'anti-christ', 'exorcists']
# ['florida', 'motel', 'finances', 'single father', 'mother son relationship']
# ['time travel', 'sequel', 'hot tub', 'duringcreditsstinger']
# ['celebrity', 'money', 'temptation', 'wealthy man', 'excess']
# ['nan']
# ['poker', 'gambling', 'casino', 'new orleans', 'roulette']
# ['spacecraft', 'experiment', 'simulation', 'space', 'astronaut']
# ['pixar animated short', 'animation', 'pixar', 'short']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['mutant', 'thriller', 'zombies', 'zombie apocalypse']
# ['nan']
# ['hiking', 'backpacker', 'friends', 'appalachian trail']
# ['clown', 'boy', 'murder', 'blood', 'child murder']
# ['terror', 'experiment', 'afterlife', 'paranormal', 'violence']
# ['gotham city', 'robin', 'super powers', 'dollmaker', 'court of owls']
# ['woman director']
# ['animal species', 'earth', 'scientist', 'globe', 'activist']
# ['europe', 'business trip']
# ['underworld', 'lost city']
# ['nan']
# ['nan']
# ['mobster', 'money problems', 'borrow', 'trouble', 'classmates']
# ['james dean', 'magazine', 'biography', 'celebrity', 'buddy']
# ['california', 'small town', 'coach', 'championship', 'woman director']
# ['nan']
# ['child prodigy', 'mathematics', 'death of father', 'coming of age', 'teenager']
# ['wife', 'murder', 'black comedy', 'suburbia', 'drug']
# ['adventure', 'animal', "noah's ark"]
# ['nan']
# ['porno star', 'craigslist', 'woman director', 'sex trade', 'porno filmmaking']
# ['gallows', 'high school', 'tragedy', 'hanging', 'found footage']
# ['sex', 'hotel', 'airport', 'infidelity', 'homosexuality']
# ['male nudity', 'rape', 'detective', 'nudity', 'group therapy']
# ['experiment', 'biography', 'controversy']
# ['france', 'hotel', '1970s', 'grief', 'travel']
# ['sport', 'racism']
# ['monster', 'island', 'halloween', 'curse', 'storm']
# ['horror', 'vision', 'pregnant', 'sight']
# ['mercenary']
# ['prostitute', 'border', 'black market', 'business woman', 'mortal danger']
# ['nan']
# ['survival']
# ['helicopter', 'underground', 'nightmare', 'quarantine', 'outbreak']
# ['orpheus', 'carnival', 'hell', 'stop motion animation', 'devil']
# ['invasion', 'robot']
# ['martial arts', 'sequel', 'revenge', 'slave']
# ['nan']
# ['nan']
# ['m.i.t.', 'hispanic', 'high school student', 'robotics club', 'car parts']
# ['appalachia', 'appalachian']
# ['mask', 'telephone', 'supernatural', 'hell', 'cop']
# ['frankenstein']
# ['mexico', 'arizona', 'cocaine', 'crack', 'murder']
# ['spoof', 'automobile racing']
# ['nan']
# ['chicago']
# ['louisiana', 'kidnapping']
# ['elves', 'musical', 'aftercreditsstinger', 'duringcreditsstinger', 'love potion']
# ['grieving widower', 'widower']
# ['chain saw', 'infection', 'quarantine', 'zombies', 'based on video game']
# ['new zealand', 'college', 'friendship', 'teenage boy', 'metal band']
# ['dc comics', 'superhero', 'super powers']
# ['country music', 'biography', 'music', 'country singer']
# ['pilot', 'suspicion', 'drone', 'u.s. military', 'air force base']
# ['anthology', 'woman director', 'horror anthology']
# ['nan']
# ['nan']
# ['mother daughter relationship', 'rock music', 'girl', 'father daughter relationship', 'boyfriend']
# ['biography', 'sport', 'tour de france']
# ['nan']
# ['virgin', 'summer camp', 'movie in movie', 'murder', 'slow motion scene']
# ['nan']
# ['woman director', 'christmas']
# ['magazine', 'music']
# ['nan']
# ['secret identity', 'hologram', 'based on cartoon', 'based on tv series', 'rock band']
# ['based on novel', 'woman director']
# ['grizzly bear', 'wilderness', 'alaska', 'survival', 'bear']
# ['germany', 'italy', 'france', 'usa', 'portugal']
# ['africa', 'based on novel', 'child soldier']
# ['santa claus', 'christmas', 'krampus']
# ['nan']
# ['nan']
# ['christmas']
# ['nan']
# ['nan']
# ['serial killer', 'tied feet', 'tied up while barefoot']
# ['based on novel']
# ['sadomasochism', 'lesbian', 'butterfly', 'lesbian love', 'autumn']
# ['diner', 'woman director']
# ['woman director']
# ['nan']
# ['high school reunion']
# ['nan']
# ['nan']
# ['nan']
# ['jazz', 'biography', 'historical figure']
# ['nan']
# ['witch', 'based on novel', 'halloween', 'death', 'evil']
# ['nan']
# ['hostage', 'officer', 'chaos', 'daughter', 'police']
# ['exploitation', 'sequel', 'gore', 'b movie', 'graphic violence']
# ['nan']
# ['nan']
# ['terror', 'countryside', 'secret', 'supernatural', 'spirit']
# ['school', 'ghost']
# ['monster', 'mutation', 'machete', 'shark', 'pacific garbage patch']
# ['louisiana', 'navy seal', 'zombies', 'zombie violence', 'infected']
# ['nan']
# ['father-son relationship', 'prostitute', 'magazine', 'escort service', 'writer']
# ['child abuse', 'sadism', 'female friendship', 'afterlife', 'buried alive']
# ['dark']
# ['nan']
# ['found footage', 'area 51']
# ['earthquake', 'los angeles', 'family', 'tv', 'seismologist']
# ['nan']
# ['identity', 'unemployment', 'dystopic future', 'woman director', 'corporation']
# ['birthday', 'chicken', 'food']
# ['nan']
# ['australia', 'missing child', 'outback', 'alcoholic drink', 'troubled marriage']
# ['cia', 'assassin', 'romance', 'neighbor', 'teenager']
# ['murder', 'true crime', 'tv movie']
# ['biography', 'soccer player']
# ['cult', 'scientology']
# ['woman director']
# ['world war ii', 'nazis']
# ['post-apocalyptic', 'dystopia', 'gore', 'bmx', 'violence']
# ['princess', 'barbie doll']
# ['survival', 'execution', 'stranger', 'no memory']
# ['nan']
# ['white trash']
# ['minions']
# ['widow', 'friendship']
# ['nan']
# ['technology', 'computer', 'history', 'apple']
# ['babysitter', 'escort service', 'high school', 'hooker', 'babysitting']
# ['baby', 'expecting', 'neighbors']
# ['africa', 'monster', 'sequel', 'creature', 'graboids']
# ['hostage', 'based on true story', 'murder', 'independent film', 'single mother']
# ['nan']
# ['maze', 'labyrinth', 'claustrophobic']
# ['small town', 'sex scene', 'woman in lingerie']
# ['small town', 'vampire', 'alien', 'zombies', 'teenager']
# ['van', 'revenge', 'murder', 'kidnapping', 'gore']
# ['dc comics', 'joker', 'superhero', 'super powers']
# ['nan']
# ['nan']
# ['cosmonaut', 'marine researchers', 'crab boat', 'bering sea', 'beluga whale']
# ['super powers']
# ['nan']
# ['disappearance', 'woman director']
# ['nan']
# ['gay', 'sweden', 'queen', 'banquet', 'based on true story']
# ['blues music', 'woman director']
# ['experiment', 'psychology', 'government', 'weapon', 'supernatural']
# ['new york', 'detective', 'smoking', 'underground', 'hamster']
# ['nan']
# ['nan']
# ['himalaya', 'climbing', 'india', 'mountaineering', 'woman director']
# ['nan']
# ['woman director']
# ['photographer', 'surgeon', 'orchestra', 'doctor', 'car accident']
# ['witch', 'woman director']
# ['florida', 'nasa', 'tornado', 'sequel', 'space']
# ['cat and mouse', 'family', 'revenge drama']
# ['fighter', 'motos']
# ['new york', 'nightclub', 'party', 'manhattan new york city', 'promoter']
# ['based on true story', 'kidnapping', 'true crime', 'woman director', 'abduction']
# ['hospital', 'church']
# ['monster', 'mutant', 'lava', 'volcano', 'los angeles']
# ['woman director']
# ['superhero team', 'super powers']
# ['nan']
# ['nan']
# ['suicide', 'adolescence', 'based on true story', 'magic realism']
# ['camping', 'based on true story', 'woods', 'gore', 'survival']
# ['god', 'woman director']
# ['nan']
# ['woman director']
# ['male nudity', 'female nudity', 'sex', 'nudity', 'post-apocalyptic']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['interview', 'filmmaking', 'retrospective', 'moviemaking']
# ['sex', 'suicide attempt', 'nudity', 'love', 'car accident']
# ['suicide', 'bullying', 'revenge']
# ['new zealand', 'haunting', 'farmhouse', 'spirit', 'psychic']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['woman director']
# ['terror', 'monster', 'car breakdown', 'tractor', 'vampire']
# ['american football', 'biography', 'sport', 'championship']
# ['found footage']
# ['nan']
# ['road trip', 'granddaughter']
# ['tattoo', 'tattooing']
# ['europe', 'camp', 'slasher', 'disease']
# ['possession']
# ['hong kong', 'expatriate', 'woman director']
# ['nan']
# ['mayor', 'politics', 'murder', 'tv mini-series', 'racism']
# ['hitchhiker', 'injured leg', 'car accident', 'trapped', 'car']
# ['nan']
# ['stalking', 'bully', 'hacking', 'teenager', 'computer hacker']
# ['nan']
# ['education', 'terrorism', 'activist', 'nobel peace prize winner']
# ['criminal', 'hometown']
# ['christian']
# ['tennis', 'tennis player', 'sport', 'mockumentary']
# ['nan']
# ['high school', 'teen movie', 'teen', 'beach movie']
# ['dancing', 'gymnastics', 'biography', 'sport', 'car accident']
# ['drug']
# ['summer', 'lifeguard', 'staten island new york city']
# ['nan']
# ['nan']
# ['nan']
# ['genetics', 'memory', 'accident']
# ['independent film', 'psychological thriller']
# ['nan']
# ['nan']
# ['voice', 'child prodigy', 'singer', 'racism', 'civil rights']
# ['nan']
# ['press', 'nazis', 'trial']
# ['nan']
# ['interview', 'archive footage', 'hollywood', 'filmmaking', 'death']
# ['nan']
# ['nan']
# ['drug use']
# ['nan']
# ['nan']
# ['parapsychology']
# ['suicide', 'taxi', 'australia', 'cancer', 'doctor']
# ['agoraphobia']
# ['mind control', 'rescue', 'search', 'plague', 'mining accident']
# ['christmas']
# ['female nudity', 'shower', 'ax', 'swamp', 'murder']
# ['based on true story', 'evil doll', 'haunting', 'possessed']
# ['father-son relationship', 'small town', 'dance', 'music', 'grief']
# ['nan']
# ['pop culture', 'pop singer', 'pop star', 'music', 'concert']
# ['nan']
# ['ukraine', 'serial killer', 'ghost', 'seance', 'pseudo documentary']
# ['nan']
# ['internet', 'crime', 'drug']
# ['pop culture', 'fan culture', 'documentary', 'toys']
# ['comedian', 'documentary', 'taboo', 'richard pryor', 'woman director']
# ['pastor', 'archaeologist', 'holy land']
# ['male nudity', 'female nudity', 'nudity', 'knife', 'police']
# ['nan']
# ['manipulation', 'politics', 'war', 'control', 'fear']
# ['exorcism', 'possession']
# ['nan']
# ['nan']
# ['defy media']
# ['behind the scenes', 'making of']
# ['nan']
# ['woman director']
# ['robbery']
# ['love triangle', 'trainers', 'client plans', 'business expansion']
# ['sister sister relationship', 'coverup', 'woman director', 'fresno california', 'accidental crime']
# ['secret', 'telepathy', 'technology', 'invention', 'government']
# ['woman director']
# ['nan']
# ['nan']
# ['nan']
# ['sex', 'bondage', 'nudity', 'seduction', 'bdsm']
# ['reality tv', 'conspiracy', 'zombies', 'zombie apocalypse']
# ['nan']
# ['hitman', 'gangster', 'inner city']
# ['time travel', 'friendship']
# ['woman director']
# ['nan']
# ['depression', 'biography', 'drug']
# ['nan']
# ['nan']
# ['nan']
# ['christian']
# ['baby', 'adoption', 'violence', 'woman director', 'tv movie']
# ['art', 'ellis island']
# ['suicide attempt', 'high school', 'loneliness', 'death', 'first love']
# ['biography', 'woodstock', 'music band', 'rock concert', 'woman director']
# ['nan']
# ['nan']
# ['haunted house', 'bed and breakfast place', 'new england', 'young couple']
# ['sex', 'stand-up', 'stand up comedy']
# ['dysfunctional family', 'alcohol problems']
# ['biography', 'rhythm and blues', 'crack cocaine', 'woman director', 'lifetime']
# ['nan']
# ['keith richards', 'documentary', 'rock band', 'blues music', 'netflix']
# ['rape', 'landmine', 'nudity', 'tourist', 'girlfriend']
# ['canada', 'halloween', 'farm', 'gore', 'decapitation']
# ['nan']
# ['nan']
# ['bloodthirstiness', 'zombies', 'scientist', 'universal cure']
# ['tyrannosaurus rex', 'dinosaur', 'raptor']
# ['relationship problems', 'relationship', 'violence', 'woman director', 'young adult']
# ['nan']
# ['nan']
# ['record industry']
# ['space', 'astronaut']
# ['nan']
# ['taxi', 'prostitute', 'transsexuality', 'sex', 'taxi driver']
# ['suicide', 'blindfold', 'forest', 'ghost story', 'pet dog']
# ['stockholm syndrome', 'woman director', 'abduction', 'biological parents']
# ['tokusatsu', 'dystopic future', 'fan film', 'power rangers', 'short']
# ['female nudity', 'lesbian kiss', 'lesbian couple', 'loneliness', 'new york city']
# ['nan']
# ['factory worker', 'textile industry', 'documentary', 'economics', 'fashion']
# ['japan', 'language barrier', 'treasure hunt', 'north dakota', 'character name in title']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['teenage girl', 'woman director']
# ['nan']
# ['stand-up', 'stand up comedy', 'aftercreditsstinger', 'duringcreditsstinger', 'netflix']
# ['obsession', 'barber']
# ['nan']
# ['nan']
# ['mustang', 'car', 'corporation', 'henry ford family', 'car factory']
# ['nan']
# ['feminism', 'sexism', 'young boy', 'gender roles', 'misogyny']
# ['gunshot wound', 'private investigator', 'reneactment', 'possible suicide']
# ['england', 'based on novel', 'island', 'murder', 'agatha christie']
# ['vampire', 'office work']
# ['nan']
# ['comedian', 'insult', 'stand-up', 'tv special', 'roast']
# ['transsexuality', 'romance', 'gay romance', 'relationship', 'transsexual']
# ['biography']
# ['nan']
# ['animation']
# ['sexuality', 'superhuman', 'superpower', 'making of', 'social issues']
# ['road trip', 'survival', 'agoraphobia', 'attack', 'fear']
# ['prison', 'prisoner', 'death row', 'reenactment', 'legal system']
# ['nan']
# ['cult', 'resurrection', 'possession', 'devil', 'demon']
# ['nan']
# ['stand up comedy', 'childhood sexual abuse']
# ['nan']
# ['wedding']
# ['nan']
# ['identity', 'possession', 'disorder']
# ['nan']
# ['monster', 'nightmare', 'biography', 'art']
# ['cheating', 'male female relationship', 'lgbt', 'young love', 'woman director']
# ['miracle', 'tragedy']
# ['teleportation', 'hell', 'portal', 'demon']
# ['music']
# ['nan']
# ['cartoon']
# ['stand up comedy']
# ['post traumatic stress  disorder', 'van', 'road trip', 'murder', 'kidnapping']
# ['london', 'based on novel', 'medium', 'ghost hunting', 'ghost hunter']
# ['nan']
# ['nan']
# ['casino']
# ['stand-up', 'stand up comedy']
# ['brother brother relationship', 'father-son relationship', 'manhattan new york city', 'woman director', 'confinement']
# ['fight', 'boxer', 'bronx', 'better life']
# ['stand up comedy']
# ['pimp', 'yoga instructor', 'woman director', 'sex worker', 'deadbeat boyfriend']
# ['upper class', 'middle class', 'working class', 'economics', 'inequality']
# ['independent film']
# ['wife husband relationship', 'haunted house', 'relocation', 'neighbor', 'mother daughter relationship']
# ['woman director']
# ['small town', 'racist', 'north dakota', 'racism', 'white supremacists']
# ['stonewall riot']
# ['nan']
# ['infection', 'sequel', 'virus', 'body horror']
# ['dark comedy']
# ['nan']
# ['nan']
# ['breast cancer', 'woman director']
# ['mistaken identity', 'coworker relationship', 'toy factory', 'christmas']
# ['nan']
# ['cult', 'satire', 'comedy', 'witty', 'making of']
# ['sport', 'alcoholism', 'soccer']
# ['nan']
# ['nan']
# ['miami', 'chicago', 'television', 'politics', 'intellectual']
# ['prison', 'detective', 'prisoner', 'prison warden', 'revenge']
# ['nan']
# ['nan']
# ['space battle', 'animation', 'space opera', 'military']
# ['nan']
# ['nan']
# ['nan']
# ['experiment', 'locked in a room', 'drug trial']
# ['spoof', 'zombies']
# ['nan']
# ['school', 'teen']
# ['twin sister', 'woman director', 'sisterhood']
# ['murder', 'crime', 'real life']
# ['self-defense', 'car mechanic', 'graduation', 'high school', 'shooting']
# ['nan']
# ['nan']
# ['small town', 'independent film', 'coming of age', 'rural', 'adolescent boy']
# ['suicide', 'underground', 'cult', 'buddy']
# ['nan']
# ['nan']
# ['hotel', 'bank', 'spaghetti', 'punk', 'nintendo']
# ['video game', 'journalist', 'ghetto', 'biography', 'christian']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['video game', 'games', 'arcade', 'nibbler']
# ['nan']
# ['stand up comedy']
# ['woman director']
# ['individual', 'sport', 'baskeball']
# ['nan']
# ['saving the world', 'artificial intelligence', 'father-son relationship', 'single parent', 'nasa']
# ['marvel comic', 'spaceship', 'space', 'scene during end credits', 'outer space']
# ['washington d.c.', 'future', 'shield', 'marvel comic', 'comic']
# ['hitman', 'revenge', 'murder', 'gangster', 'dog']
# ['resistance', 'post-apocalyptic', 'dystopia', 'war', 'sequel']
# ['corruption', 'elves', 'dwarves', 'orcs', 'middle-earth (tolkien)']
# ['brother brother relationship', 'hero', 'talent', 'revenge', 'best friend']
# ['gay', 'england', 'world war ii', 'mathematician', 'biography']
# ['based on novel', 'maze', 'post-apocalyptic', 'dystopia', 'escape']
# ['times square', 'superhero', 'long take', 'new york city', 'play']
# ['falsely accused person', 'based on novel', 'marriage crisis', 'disappearance', 'cheating husband']
# ['world war ii', 'nazis', 'war', 'nazi germany', 'panzer']
# ['night watchman', 'museum', 'natural history', 'history', 'smithsonian']
# ['based on novel', 'dystopia', 'youth', 'dystopic future', 'caste system']
# ['1970s', 'mutant', 'time travel', 'marvel comic', 'based on comic book']
# ['artificial intelligence', 'intelligence', 'drug mule', 'futuristic', 'drug']
# ['martial arts', 'terrorist', 'subway', 'hero', 'mutation']
# ['marriage', 'internet', 'relationship', 'family', 'sex tape']
# ['journalism', 'underground', 'tv station', 'sociopath', 'home invasion']
# ['sequel', 'alien', 'transformers', 'giant robot', 'robot']
# ['hotel', 'painting', 'wartime', 'gunfight', 'theft']
# ['jazz', 'obsession', 'conservatory', 'music teacher', 'new york city']
# ['leader', 'colony', 'post-apocalyptic', 'dystopia', 'sequel']
# ['revenge', 'gangster', 'commando', 'faked death', 'black ops']
# ['prison', 'sequel', 'kidnapping', 'car chase', 'sex addict']
# ['marvel comic', 'sequel', 'based on comic book', 'sony', '3d']
# ['deja vu', 'time warp', 'dystopia', 'war', 'alien']
# ['cia', "coup d'etat", 'north korea', 'assassination attempt', 'evil dictator']
# ['sniper', 'biography', 'iraq', 'navy seal', 'u.s. soldier']
# ['moses', 'bible', 'ancient egypt', '3d', 'ramses']
# ['monster', 'godzilla', 'remake', 'giant monster', 'gojira']
# ['fairy tale', 'villain', 'sleeping beauty', 'dark fantasy', 'based on fairy tale']
# ['cia', 'retired', 'agent', 'month in title']
# ['death of a friend', 'ouija', 'ouija board', 'teenager', 'based on board game']
# ['father-son relationship', 'wife husband relationship', 'sacrifice', 'viking', 'sequel']
# ['friends', 'vision', 'school', 'young adult', 'followed']
# ['cia', 'arms dealer', 'sequel', 'rescue mission', 'hospital']
# ['father-son relationship', 'creativity', 'friendship', 'part live action', 'toys']
# ['male friendship', 'murder', 'suspense', 'love affair', 'apartment']
# ['magic', 'chosen one', 'sword and sorcerery', 'dark fantasy', 'witch hunter']
# ['biography', 'physicist', 'based on memoir', 'stephen hawking']
# ['corruption', 'robbery', 'nightclub', 'male friendship', 'investigation']
# ['vampire', 'dracula', 'battle', '15th century', 'ottoman empire']
# ['penguin', 'madagascar', '3d']
# ['witch', 'cinderella', 'prince', 'fairy tale', 'musical']
# ['based on graphic novel', 'ancient greece', 'duringcreditsstinger', 'sea battle', 'hand to hand combat']
# ['dystopia', 'black and white', 'based on young adult book']
# ['high school', 'undercover cop', 'buddy comedy', 'aftercreditsstinger', 'duringcreditsstinger']
# ['based on novel', 'murder', 'mafia', 'private investigator', 'new york city']
# ['england', 'train station', 'based on novel', 'bear', 'anthropomorphic animal']
# ['suicide', 'support group', 'depression', 'widower', 'grieving']
# ['father-son relationship', 'kitchen', 'restaurant owner', 'food', 'divorce']
# ['bus', 'assault rifle', 'sniper', 'machete', 'dystopia']
# ['airplane', 'the rapture', 'remake', 'pilot hero']
# ['daily life', "family's daily life", 'urban life', 'growing up', 'domestic abuse']
# ['new york city', 'crime']
# ['mercenary', 'battle', 'ancient greece', 'hercules', 'warrior']
# ['bible', 'god', 'noah']
# ['father-son relationship', 'judge', 'lawyer']
# ['nan']
# ['africa', 'blind date', 'relationship', 'family vacation', 'family']
# ['alcohol', 'baby', 'party', 'family', 'fraternity']
# ['coma', 'musician', 'teenage girl', 'car accident', 'teenager']
# ['street artist', 'dance contest', 'woman director']
# ['based on novel', 'male female relationship', 'teenage pregnancy', 'best friends in love', 'missed opportunity']
# ['amsterdam', 'based on novel', 'support group', 'cancer', 'teenager']
# ['independent film', 'eyes', 'molecular biologist']
# ['police operation', 'police officer', 'brother-in-law brother-in-law relationship', 'duringcreditsstinger', 'black men']
# ['family relationships', 'missing child', 'abduction']
# ['based on novel', '1970s', 'private investigator', 'smoking marijuana', 'los angeles']
# ['london', 'corruption', 'cia', 'terrorist', 'sniper']
# ['airplane', 'conspiracy', 'cell phone', 'hijack', 'airplane crash']
# ['nan']
# ['artificial intelligence', 'rain', 'future', 'dystopia', 'robot']
# ['dragon', 'magie', 'sorcier']
# ['crime boss', 'mobster', 'pitbull', 'brooklyn new york city']
# ['corruption', 'cyborg', 'technology', 'future', 'law']
# ['artificial intelligence', 'technology', 'nanotechnology', 'computer virus', 'super computer']
# ['woman']
# ['father-son relationship', 'egypt', 'intelligence', 'adoption', 'time travel']
# ['christmas']
# ['detective', 'dystopia', 'dominatrix', 'murder', 'suspense']
# ['fairy', 'fairy tale', 'tinkerbell']
# ['bird', 'sequel', 'jungle', 'audition', 'amazon rainforest']
# ['friendship', 'sequel', 'road movie', 'buddy comedy']
# ['amnesia', 'therapist', 'aggression', 'hospital', 'flashback']
# ['world war ii', 'nazis', 'art theft', 'post world war ii']
# ['prisoner of war', 'biography', 'sport', 'war', 'athlete']
# ['alabama', 'martin luther king', 'president', 'black american', 'civil rights']
# ['quebec', 'dysfunctional family', 'single mother', 'mother son relationship', 'behavioral disorders']
# ['surfer', 'murder', 'murderer', 'columbia', 'telephone conversation']
# ['fairy', 'fairy tale', 'curiosity', 'duringcreditsstinger', 'woman director']
# ['adventure', 'biography', 'hiking', 'based on true story', 'traveller']
# ['gladiator', 'arena', 'gladiator fight', 'lava', 'roman']
# ['nicholas sparks']
# ['musical', 'orphan', 'foster child']
# ['mental institution', 'doctor', 'mental patient', 'edgar allan poe', 'based on short story']
# ['love triangle', 'afterlife', 'day of the dead', 'bullfighting']
# ['babysitter', 'friendship', 'neighbor', 'divorce', 'child of divorce']
# ['street race', 'super cars', 'super speed', 'car', 'based on video game']
# ['sex', "new year's eve", 'one-night stand', 'snow storm', 'new york city']
# ['based on novel']
# ['nan']
# ['based on novel', 'stop motion animation', 'father daughter relationship', 'unlikely friendship', 'duringcreditsstinger']
# ['wife husband relationship', 'artist', 'court case']
# ['mobster', 'justice', 'retired', 'missing', 'missing daughter']
# ['submarine', 'captain']
# ['fairy tale', 'lighthouse', 'folk music', 'lighthouse keeper   ', 'irish']
# ['marvel comic', 'based on comic book', 'iron man', 'marvel cinematic universe', 'mandarin']
# ['hacker', 'supernatural powers', 'road trip', 'independent film', 'superpower']
# ['sex', 'based on novel', 'mystery', 'disappearance', 'missing person']
# ['tornado', 'student', 'found footage', 'disaster movie']
# ['emperor', 'chinese emperor', 'warrior']
# ['paris', 'spy', 'cia', 'terrorist', 'fight']
# ['firemen', 'national park', 'sequel', 'anthropomorphic car', 'anthropomorphic vehicles']
# ['riot', 'war', 'british', 'survival', 'soldier']
# ['drug cartel', 'dea']
# ['gunslinger', 'farmer', 'wild west']
# ['suspense', 'theft']
# ['identity', 'musician', 'music', 'friendship', 'mysterious']
# ['guantanamo bay', 'female soldier', 'female protagonist', 'american abroad', 'military police']
# ['sadistic', 'hostage', 'sociopath', 'serial killer', 'blood']
# ['mother', 'professor', 'illness']
# ['paris', 'treasure', 'catacombs', 'written by director', 'scientist']
# ['biography', 'wrestling', 'sport', 'based on true story']
# ['screenwriter', 'love', 'friends', 'romance', 'lying']
# ['woman director', 'teenage romance']
# ['dystopia']
# ['nan']
# ['based on novel', 'world war ii', 'love', 'french resistance', 'nazi occupation']
# ['sailboat', 'hotel', 'american', 'couple', 'private detective']
# ['journalist', 'one-night stand', 'blonde', 'woman', 'lost']
# ['doppelganger', 'spiders']
# ['prequel', 'evil doll', 'killer doll', 'spin off', 'doll']
# ['sleep', 'paralysis']
# ['nan']
# ['soul', 'queen', 'anti hero', 'fantasy', 'prince']
# ['male friendship', 'friendship', 'dating', 'relationship', 'duringcreditsstinger']
# ['high school', 'soccer', 'older man younger woman relationship', 'teenager', 'teenage sexuality']
# ['sport', 'duringcreditsstinger']
# ['martial arts', 'atomic bomb', 'ghetto', 'parkour', 'cops']
# ['monster', 'nightmare', 'book', 'dysfunctional family', 'single mother']
# ['nan']
# ['talent', 'music', 'school', 'singing', 'orphan']
# ['corruption', 'sheriff', 'mountains', 'wilderness', 'ambition']
# ['world war i', 'war', 'based on autobiography']
# ['brother brother relationship', 'robbery', 'bank']
# ['corruption', 'kidnapping', 'drug']
# ['new york', 'adultery', 'confession', 'brother sister relationship', 'infidelity']
# ['mi5', 'johnny worricker']
# ['series of murders']
# ['based on novel']
# ['lgbt']
# ['friendship', 'coming of age', 'mother daughter relationship', 'female protagonist', 'father daughter relationship']
# ['bar', 'halloween', 'high school', 'iraq war veteran', 'murder']
# ['nan']
# ['comedy']
# ['revenge', 'drifter', 'virginia', 'character study', 'neo-noir']
# ['english professor']
# ['istanbul', 'australia', 'farmer', 'gallipoli campaign']
# ['chile', 'gore', 'jungle', 'extreme violence', 'cannibal']
# ['provence', 'aunt', 'magician', 'spiritualist']
# ['noir', 'violence', 'girls with guns', 'anime style', 'based on anime']
# ['based on novel', 'job interview', 'bad luck', 'wish', 'one day']
# ['based on novel', 'funeral', 'dysfunctional family', 'death of father', 'man child']
# ['dancing', 'based on novel', 'revenge', 'native american', 'tied feet']
# ['prison', 'robbery', 'gold', 'boat', 'mine']
# ['self-defense', 'revenge', 'murder', 'home invasion']
# ['paranoia', 'double']
# ['squirrel', '3d animation']
# ['martial arts', 'human trafficking', 'muay thai', 'rogue cop', 'bangkok thailand']
# ['high technology', 'written by director', 'voyeurism']
# ['terrorist', 'parachute', 'president', 'air force one', 'escape']
# ['motel', 'crime boss']
# ['biography', 'based on play']
# ['duringcreditsstinger']
# ['baseball', 'sport', 'duringcreditsstinger']
# ['jew', 'independent film', 'homeschooling', 'family', 'struggling actor']
# ['semi autobiographical', 'woman director', 'bipolar', 'absent  mother', 'bipolar disorder']
# ['nan']
# ['new york', 'nanny', 'loser', 'pregnant']
# ['zodiac']
# ['wife husband relationship', 'adventure', 'romance', 'cheating husband', 'stranger']
# ['male nudity', 'scotland', 'edinburgh', 'alien', 'very little dialogue']
# ['murder', 'private detective', 'high school reunion', 'duringcreditsstinger']
# ['trip', 'travelling person', 'travel', 'search', 'pursuit']
# ['biography', 'resurrection']
# ['junk food', 'obesity', 'documentary', 'food industry', 'sugar']
# ['dc comics', 'superhero', 'based on comic book', 'spin off']
# ['naivety', 'family']
# ['dc comics', 'based on comic book', 'superhero team', 'super powers']
# ['virtual reality', 'dystopia', 'computer']
# ['haunted house', 'superstition', 'horror movie', 'home detention']
# ['series of murders']
# ['american football', 'sport', 'high school american football']
# ['sequel', 'suspense', 'made for television', 'mi5', 'caribbean island']
# ['toy', 'pixar animated short', 'toy story']
# ['cake', 'pixar animated short', 'food', 'dog', 'organic food']
# ['woman director']
# ['england', 'alcohol', 'college', 'based on play', 'wealthy']
# ['based on graphic novel', 'multiple personality', 'psychiatric']
# ['monaco', 'prince', 'reference to princess grace of monaco']
# ['infidelity', 'genetics', 'black comedy', 'cancer', 'dna testing']
# ['sexuality', 'fetish', 'couple', 'sexual experimentation', 'erotic fantasy']
# ['telepathy', 'new mexico', 'loneliness', 'ex-con', 'understated']
# ['vietnam veteran', 'murder', 'second part', 'inspired by true events']
# ['nan']
# ['cia', 'retirement', 'espionage', 'terrorism']
# ['male nudity', 'female nudity', '1970s', 'experiment', 'nudity']
# ['russian mafia', 'revenge', 'kidnapping', 'haunted by the past']
# ['terror', 'muslim', 'intelligence', 'immigrant', 'torture']
# ['comedian', 'interview', 'reporter', 'movie star', 'fiancÃ© fiancÃ©e relationship']
# ['biography', 'james brown']
# ['monster', 'darkness', 'desert', 'archaeologist', 'lost']
# ['possessed', 'demon', 'occult', 'demonic possession']
# ['suicide', 'divorce', 'gender ideals', 'actress']
# ['biography']
# ['nan']
# ['gambling', 'future', 'time travel', 'gambling debts', 'photography']
# ['infidelity', 'new york city', 'screwball comedy', 'escort', 'theater']
# ['new zealand', 'vampire', 'blood', 'mockumentary', 'zombies']
# ['montana', 'secret', 'witness', 'video', 'murder']
# ['lake', 'honeymoon', 'woods', 'sleepwalking', 'woman director']
# ['nan']
# ['asteroid', 'future', 'retro']
# ['england', 'road', 'cheating husband', 'construction site', 'one night']
# ['woman director', 'part fiction', 'docu fiction']
# ['dolphin', 'aquarium', 'swimming']
# ['hotel', 'secret', 'love', 'money', 'train']
# ['nan']
# ['black comedy']
# ['woman director']
# ['based on novel', 'haunted house', 'supernatural', 'sequel', 'haunting']
# ['nan']
# ['supernatural']
# ['musical', 'the muppets']
# ['nan']
# ['nan']
# ['nan']
# ['gun', 'thriller', 'gun battle', 'gore', 'woman']
# ['snake', 'possession', 'found footage', 'shaky camera shot', 'serial murders']
# ['canada', 'walrus', 'deception', 'search', 'first part']
# ['high school', 'teenager', 'playing against type']
# ['homeless person', 'immigrant', 'heroin', 'homelessness', 'sex scene']
# ['based on tv series', 'los angeles', 'briton abroad']
# ['supernatural', 'subjective camera', 'found footage', 'epouvante']
# ['vacation', 'family']
# ['technology', 'future', 'mind control', 'kidnapping', 'conspiracy']
# ['nan']
# ['new york', 'married couple', 'character name in title', 'moving out', 'moving']
# ['haunted house']
# ['therapist', 'musician', 'nervous breakdown', 'title based on song', 'songwriter']
# ['based on novel', 'faith', 'based on true events']
# ['motivational book']
# ['nan']
# ['biography', 'psychological thriller', 'lizzie borden', 'dramatization']
# ['monster', 'post-apocalyptic', 'war', 'sequel', 'alien']
# ['woman director', 'activist']
# ['nan']
# ['holiday', 'australia', 'vacation']
# ['musical', 'barbie']
# ['new york']
# ['national security agency', 'woman director', 'edward snowden']
# ['paris', 'dancing', 'france', 'adultery', 'jealousy']
# ['alaska', 'family', 'nature', 'bears']
# ['nan']
# ['nan']
# ['mythology', 'zeus', 'ancient greece', 'demigod', 'city of argos']
# ['male nudity', 'sex', 'menage a trois', 'wedding ring', 'blood']
# ['beaver', 'zombies', 'animal attack']
# ['nan']
# ['nan']
# ['grandfather granddaughter relationship', 'neighbor', 'wealthy', 'elderly', 'estrangement']
# ['painter']
# ['male nudity', 'womanizer', 'bare chested male', 'gym', 'penis']
# ['nan']
# ['adoption', 'werewolf']
# ['london', 'based on novel', 'bachelor', 'flat', 'gadget']
# ['nan']
# ['authority', 'vampire', 'half vampire', 'danger of life', 'protection']
# ['new york', 'couple', 'loss of a child']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['refugee', 'kansas', 'sudanese']
# ['police', 'baton rouge']
# ['female nudity', 'sex', 'shower', 'sauna', 'nudity']
# ['drug mule', 'drug']
# ['anthology', 'woman director', 'horror anthology']
# ['sequel', 'creature', 'shark', 'made for television', 'creature feature']
# ['homosexuality', 'independent film', 'new york city', 'gay wedding']
# ['woman director']
# ['nan']
# ['love triangle', 'love', 'irish', 'valet', 'woman director']
# ['grandfather', 'betrayal', 'pigeon']
# ['gambling', 'casino', 'boss', 'lithuania', 'murder']
# ['nan']
# ['cannibal']
# ['talk show', 'black comedy', 'woman director', 'mental disorders', 'winning lottery']
# ['dystopia', 'mind control', 'alien invasion', 'desert warfare', 'war of attrition']
# ['suicide', 'woman director']
# ['new york', 'couple', 'loss of a child']
# ['gunshot wound', 'cottage', 'doctor', 'woman director']
# ['santa claus']
# ['nan']
# ['prison', 'mercenary', 'rescue', 'mockbuster']
# ['district attorney']
# ['murder investigation']
# ['nan']
# ['woman director']
# ['hostage', 'sequel', 'rampage', 'massacre']
# ['vampire', 'female vampire', 'iranian', 'woman director']
# ['based on short film', 'new york city', 'babysitting', 'attempted suicide', 'uncle niece relationship']
# ['found footage', 'vampiros']
# ['princess']
# ['infidelity', 'obsession', 'lie', 'sin', 'interracial relationship']
# ['talent', 'success', 'musician', 'woman director']
# ['nan']
# ['royalty', 'christmas']
# ['nan']
# ['high school', 'woods', 'gore', 'graphic violence', 'slasher']
# ['nan']
# ['serial killer', 'frightening visions', 'parent killed']
# ['wife husband relationship', 'stress', 'children', 'mother daughter relationship', 'parenthood']
# ['dc comics', 'superhero', 'based on comic book', 'robin', 'super powers']
# ['alien', 'found footage']
# ['nan']
# ['yakuza', 'marine', 'fighting']
# ['nan']
# ['fairy', 'castle', 'sleeping beauty', 'forest', 'dragon']
# ['nan']
# ['nan']
# ['bikini', 'curse', 'hot tub', 'scientist', 'shark']
# ['rain', 'future', 'water', 'dystopia', 'survivor']
# ['kidnapping', 'twitter', 'actor']
# ['revenge', 'tv', 'mystery writer']
# ['prison', 'mentor', 'redemption', 'criminal']
# ['independent film', 'woman director']
# ['friendship', 'high school', 'equestria girls', 'friendship is magic']
# ['love triangle', 'middle east', 'fight', 'missile', 'pilot']
# ['musical', 'masked killer', 'slasher']
# ['sword', 'war', 'revenge', 'medieval', 'saxons']
# ['nudity', 'nerd', 'campus', 'zombies']
# ['adoption', 'daughter', 'travel', 'couple', 'cheat']
# ['robbery', 'wrestling', 'las vegas nevada', 'bachelorette party']
# ['gambling', 'gun', 'professor', 'beating', 'gambler']
# ['sport', 'mixed martial arts']
# ['nan']
# ['italian', 'boston', 'mafia', 'gang', 'mobster']
# ['lesbian', 'extramarital affair', 'actor']
# ['nan']
# ['revenge', 'road movie']
# ['newfoundland', 'doctor', 'bribery', 'new job', 'hospitality']
# ['rise and fall', 'movie studio', 'b movie', 'hollywood', 'filmmaking']
# ['nan']
# ['wife murder', 'murder plot']
# ['cabin', 'engagement', 'party', 'woods', 'alien']
# ['nan']
# ['woman director']
# ['desperation', 'elite', 'fame', 'hollywood', 'initiation']
# ['biography', 'mexican', 'hollywood star']
# ['from rags to riches', 'politician', 'inspiring story', 'filipino', 'pacquiao']
# ['supernatural', 'flight', 'number in title', 'ghost', 'pacific  ocean']
# ['assassin', 'trapped', 'trapped in an elevator', 'elevator']
# ['diplomat', 'extramarital affair', 'novelist']
# ['angry video game nerd']
# ['nan']
# ['australia', 'party', 'end of the world', 'apocalypse']
# ['woman director']
# ['nan']
# ['sadistic', 'grandfather', 'mansion', 'captive', 'molestation']
# ['biography', 'based on true story', 'true crime', 'religious fundamentalism']
# ['nan']
# ['war', 'disaster', 'virus', 'plague', 'doubtful survival']
# ['wife', 'musical', 'marriage', 'divorce']
# ['pharmacist', 'black comedy', 'trophy wife']
# ['suicide', 'island', 'infection', 'quarantine', 'prequel']
# ['texas', 'murder', 'heist', 'teenager', 'empty safe']
# ['new york', 'couple', 'loss of a child']
# ['elementary school', 'teacher', 'zombies', 'virus', 'child']
# ['found footage']
# ['prequel', 'leprechaun']
# ['nan']
# ['viking', 'man hunt', 'battle for survival', 'berserkers', 'saxons']
# ['based on magazine article']
# ['nan']
# ['widower']
# ['professor', 'teaching', 'pommy']
# ['nan']
# ['surfing', 'woman director']
# ['chess', 'new zealand', 'based on true story', 'bipolar']
# ['zombies', 'zombie apocalypse']
# ['christian', 'religion']
# ['survival', 'lifeboat', 'bombardier']
# ['experiment', 'health', 'food industry', 'sugar', 'health food']
# ['nan']
# ['nan']
# ['look-alike', 'drug lord']
# ['marvel comic']
# ['nan']
# ['nan']
# ['superhero', 'marvel cinematic universe']
# ['mumblegore']
# ['nan']
# ['weekend', 'therapist', 'marriage', 'dilemma', 'escape']
# ['exorcism', 'possession', 'demon', 'exorcist', 'demonic possession']
# ['female nudity', 'sex', 'drowning', 'cheating', 'nudity']
# ['nan']
# ['black comedy', 'woman director']
# ['gay', 'aids', 'homosexuality', 'epidemic']
# ['cult']
# ['found footage']
# ['police', 'violence']
# ['based on novel', 'baltimore', 'kidnapping', 'missing child', 'baltimore maryland']
# ['rape', 'murder', 'independent film', 'mistaken identity', 'home invasion']
# ['island', 'children', 'dinosaur']
# ['based on true story', 'cancer', 'lap dance', 'female stripper', 'exotic dancer']
# ['scotland', 'police', 'murder', 'violence', 'stranger']
# ['romantic comedy']
# ['dance', 'high school', 'teenager', 'teen comedy', 'obedience']
# ['nan']
# ['dominatrix']
# ['afghanistan', 'bravery', 'british army', 'grenade', 'biography']
# ['nan']
# ['high school', 'student', 'prankster']
# ['writer', 'woman director']
# ['nan']
# ['woman director']
# ['australian', 'australia', 'police', 'dirty cop', 'hit and run']
# ['post-apocalyptic', 'war', 'mecha', 'cyberpunk']
# ['nan']
# ['art critic']
# ['sequel', 'trucker']
# ['nan']
# ['nan']
# ['australian', 'slasher']
# ['video game', 'nerd', 'arcade', 'computer games', 'atari']
# ['nan']
# ['paris', 'writer', 'apartment']
# ['biography', 'wrestling', 'sport', 'woman director']
# ['brother brother relationship', 'single parent', 'running', 'guitar', 'bar']
# ['asteroid', 'blood splatter', 'outer space', 'alien invasion', 'fire department']
# ['father-son relationship', 'rock band', 'grieving father']
# ['nan']
# ['london', 'dancing', 'secret agent', 'revenge', 'heist']
# ['martial arts', 'amnesia', 'based on video game']
# ...
# ['suspense']
# ['wilderness', 'boy', 'best friend']
# ['independent film', 'woman director']
# ['female nudity', 'monster', 'hero', 'nudity', 'halloween']
# ['thriller', 'kidnapping']
# ['mexico', 'sailing', 'funeral', 'wife', 'daughter']
# ['android', 'child murderer', 'sequel', 'metal', 'mutilations']
# ['arranged marriage', 'failure', 'near future', 'woman director']
# ['fashion', 'month in title']
# ['nan']
# ['based on novel', 'independent film']
# ['nan']
# ['american football', 'jealousy', 'secret', 'small town', 'obsession']
# ['female nudity', 'based on novel', 'stripper', 'flop', 'black comedy']
# ['illinois', 'independent film', 'white castle', 'woman director']
# ['nan']
# ['nan']
# ['nan']
# ['nan']
# ['claim in title', 'rock documentary', 'soda bottle', 'statement in title', 'led zeppelin']
# ['amnesia', 'suspense', 'serial killer', 'psychic', 'investigator']
# ['gay', 'fame', 'mockumentary', 'hollywood', 'lgbt']
# ['island', 'magic', 'adventure', 'foreign language', 'based on tv series']
# ['independent film']
# ['nan']
# ['nan']
# ['megaphone', 'feminism', 'future', 'wormhole', 'alien life-form']
# ['nan']
# ['nurse', 'prophecy', 'cia', 'undercover', 'mass murder']
# ['detective', 'cocaine', 'male friendship', 'strip club', 'costume']
# ['middle-earth (tolkien)', 'the lord of the rings']
# ['suspense']
# ['west virginia', 'revenge', 'rifle', 'occult']
# ['nan']
# ['college', 'sorority', 'rivalry', 'young adult']
# ['independent film']
# ['nan']
# ['nan']
# ['duringcreditsstinger']
# ['independent film']
# ['suspense', 'independent film']
# ['nan']
# ['witness protection', 'comedy', 'duringcreditsstinger']
# ['cartoon', 'surrealism', 'dog', 'garfield']
# ['brother sister relationship', 'broken neck', 'curse', 'stabbing', 'gothic']
# ['suspense']
# ['wormhole', 'sand']
# ['live performance', 'spoof', 'live audience', 'stand up comedian']
# ['nan']
# ['nan']
# ['holiday', 'gay', 'coming out', 'gay romance', 'gay teenager']
# ['christian', 'independent film']
# ['nan']
# ['nan']
# ['nan']
# ['suspense']
# ['nudity', 'white trash', 'jack daniels', 'marijuana']
# ['love', 'moccia']
# ['independent film']
# ['nan']
# ['prequel', 'child driving tractor', 'hit by a truck', 'killer scarecrow']
# ['nan']
# ['nan']
# ['underground', 'vampire', 'zombies']
# ['halloween', 'slapstick', 'duringcreditsstinger']
# ['diary', 'anne frank', 'jewish', 'girl', 'nazi occupation']
# ['gun', 'loser', 'sport', 'beating', 'diner']
# ['ferrari', 'desert']
# ['nan']
# ['female nudity', 'underwear', 'strip club', 'mute']
# ['nan']
# ['aunt', 'duringcreditsstinger']
# ['gangster boss', 'birthmark', 'pact with the devil']
# ['dystopia']
# ['independent film', 'woman director']
# ['nan']
# ['post-apocalyptic', 'global warming', 'woman director']
# ['tour', 'heavy metal', 'live concert', 'loud music']
# ['plants', 'animal species', 'biology', 'wildlife', 'ecology']
# ['costume', 'song', 'village', 'promise', 'ballet']
# ['psychopathic killer', 'metal skull mask', 'slaughter']
# ['stalking', 'mountain climbing', 'elimination derby', 'blockage']
# ['independent film', 'duringcreditsstinger']
# ['conspiracy theory']
# ['murder', 'dark comedy', 'crime family']
# ['nan']
# ['musical']
# ['paranormal', 'fake documentary', 'demonic possession', 'based on a supposedly true story', 'no ending credits']
# ['nan']
# ['inspiration']
# ['england', 'leeds united', 'sport', 'brighton', 'soccer']
# ['capitalism', 'economics', 'oil industry', 'prediction', 'financial crisis']
# ['nan']
# ['nan']
# ['independent film']
# ['french movies']
# ['criminal']
# ['woman director']
# ['independent film']
# ['dancing', 'west virginia', 'independent film']
# ['last judgment', 'afterlife', 'paranormal', 'barker']
# ['beauty contest']
# ['nan']
# ['shakespeare adaptation', 'based on play']
# ['film director', 'interview', 'independent film', 'filmmaker', 'filmmaking']
# ['alcohol', 'restaurant', 'immigrant', 'bus ride', 'bicycle']
# ['alien abduction']
# ['cheerleader', 'sport', 'high school', 'malibu', 'cheerleading']
# ['nan']
# ['zoo', 'delinquent', 'police', 'criminal']
# ['duringcreditsstinger']
# ['nan']
# ['shop', 'store window', 'toy shop', 'child in peril', 'doll']
# ['nan']
# ['nan']
# ['nan']
# ['mental breakdown', 'independent film', 'writer', 'bathtub']
# ['indian food', 'queens new york city', 'business card', 'muslim american']
# ['nan']
# ['roommate', 'romantic comedy', 'independent film', 'roommate relationship']
# ['nan']
# ['nan']
# ['woman director']
# ['fraud', 'woman director', 'online lying', 'connect to real life']
# ['mass murder', 'murder', 'director', 'horror movie', 'jason vorhees']
# ['japan', 'supernatural powers', 'alien']
# ['romantic comedy', 'bollywood']
# ['nan']
# ['slasher', 'bestiality', 'raped by animal', 'evil puppet', 'turkey the bird']
# ['stand-up', 'stand up comedy']
# ['nan']
# ['horror', 'mystery', 't-horror']
# ['loss of lover', 'dream', 'sleep', 'subconsciousness', 'heist']
# ['malibu', 'marvel comic', 'comic', 'superhero', 'revenge']
# ['based on novel', 'fictional place', 'queen', 'alice in wonderland', 'fantastic']
# ['competition', 'taxi', 'dancer', 'obsession', 'paranoia']
# ['corruption', 'isolation', 'radio', 'magic', 'teleportation']
# ['adoptive father', 'orphanage', "life's dream", 'rival', 'stealing']
# ['tattoo', 'martial arts', 'sniper', 'island', 'mercenary']
# ['flying', 'blacksmith', 'arena', 'island', 'night']
# ['based on novel', 'island', 'hurricane', 'investigation', 'psychiatric hospital']
# ['artificial intelligence', 'dystopia', 'thriller', 'alternative', 'imax']
# ['hostage', 'horse', 'fairy tale', 'musical', 'princess']
# ['hostage', 'college', 'toy', 'barbie', 'animation']
# ['bomb', 'usa', 'assassination', 'taxi', 'spy']
# ['mountains', 'despair', 'adventure', 'utah', 'alone']
# ['lie', 'high school', 'school', 'teen movie', 'rumor']
# ['based on novel', 'magic', 'good vs evil', 'king', 'narnia']
# ['flying', 'confession', 'crime fighter', 'secret identity', 'superhero']
# ['paris', 'hotel', 'false identity', 'undercover agent', 'romance']
# ['persia', 'sandstorm', 'brother against brother', 'armageddon', 'regent']
# ['robin hood', 'archer', 'knight', 'sherwood forest', 'bow and arrow']
# ['loss of father', 'father murder', 'texas ranger', 'alcoholism', 'betrayal']
# ['hades', 'mythology', 'greek mythology', 'zeus', 'medusa']
# ['witch', 'fire', 'wolf', 'fountain', 'magic']
# ['italy', 'letter', 'romantic comedy', 'american abroad', 'boyfriend girlfriend']
# ['hacker', 'hacking', 'creator', 'social network', 'deposition']
# ['whipping', 'hipster', 'underage girlfriend', 'animated flashback', "character's point of view camera shot"]
# ['nurse', 'cat', 'father-in-law', 'vomit', 'kids and family']
# ['hunter', 'predator', 'yakuza', 'hunting human beings', 'alien life-form']
# ['monster', 'greek mythology', 'god', 'poseidon Â\xa0', 'lightning bolt']
# ['runaway train']
# ['ogre', '3d']
# ['based on novel', 'army', 'love', 'u.s. soldier', 'nicholas sparks']
# ['war crimes', 'military court', 'military service', 'double crossed', 'aftercreditsstinger']
# ['cia', 'retirement', 'shot to death', 'sniper rifle', 'retired']
# ['illegal immigration', 'immigration law', 'machete', 'politician', 'death of a child']
# ['overweight', 'swing', 'foot', 'convertible', 'arrow']
# ['book', 'post-apocalyptic', 'dystopia', 'faith', 'blind']
# ['date', 'corruption', 'taxi', 'expensive restaurant', 'wife husband relationship']
# ['money laundering', 'ambulance', 'boston', 'massachusetts', 'bank manager']
# ['new york', 'father-son relationship', 'grieving', 'romantic drama', 'young adult']
# ['vampire', 'graduation', 'immortality', 'werewolf']
# ['saving the world', 'date', 'prison', 'secret identity', 'fish']
# ['fire', 'ice', 'war ship', 'prince', 'kingdom']
# ['ceo', 'fire truck', 'starts with narration', 'shot in the shoulder', 'zip line']
# ['hero', 'vampire', 'supernatural', 'revenge', 'rivalry']
# ['medium', 'evil spirit', 'house warming', 'aftercreditsstinger']
# ['musical', 'duringcreditsstinger', '3d']
# ['great britain', 'radio', 'monarchy', 'radio transmission', 'royal family']
# ['male nudity', 'female nudity', 'letter', 'love', 'viagra']
# ['escape', 'india', 'gulag', 'american', 'thug']
# ['dystopia', 'evil corporation', 'repo man', 'aftercreditsstinger']
# ['new york', 'infidelity', 'ex-girlfriend', 'loyalty', 'trip']
# ['spy', 'airport', 'gas station', 'garage', 'pilot']
# ['prison', 'showdown', 'shotgun', 'fight', 'prison cell']
# ['indonesia', 'female protagonist', 'india', 'divorce', 'bali']
# ['dancing', 'nurse', 'depression', 'classroom', 'bridge']
# ['bounty hunter', 'ex husband ex wife relationship']
# ['taxi', 'bar', 'wales', 'marriage proposal', 'airplane']
# ['weapon of mass destruction', 'baghdad', 'iraqiÂ\xa0']
# ['journalist', 'forbidden love', 'princess', 'royal court']
# ['kiss', 'sperm bank', 'romantic comedy', 'male female relationship', 'doctor']
# ['brother brother relationship', 'based on novel', 'sailing', 'ghost', 'young adult']
# ['alcohol', 'single parent', 'baby', 'restaurant', 'aquarium']
# ['women', '1970s', 'publicity', 'iron', 'music']
# ['flower', 'married couple', 'florist', 'kiss', 'single']
# ['monster', 'remake', 'creature', 'bathtub', 'teeth']
# ['london', 'flying', 'countryside', 'magic', 'fairy']
# ['survivor', 'self help guru', 'stabbed in the mouth', 'tricycle', 'prosthetic arm']
# ['duringcreditsstinger']
# ['highway', 'slacker', 'hitchhiker', 'wallet', 'sunglasses']
# ['london', 'mother', 'robbery', 'detective', 'assassin']
# ['paris', 'cia', 'undercover', 'explosive', 'pimp']
# ['london', 'cia', 'war crimes', 'tony blair', 'author']
# ['suicide', 'depression', 'independent film', 'coming of age', 'teen movie']
# ['evidence', 'passport', 'argument', 'county jail', 'fingerprints']
# ['freddy krueger', 'reboot']
# ['hospital', 'black ops', 'reference to macgyver', 'sucked into jet engine']
# ['sport', 'irish american', 'documentary crew', 'lowell massachusetts', 'blue collar worker']
# ['aftercreditsstinger']
# ['cabin', 'chainsaw', 'hillbilly', 'body in chipper', 'cut off jeans']
# ['gunslinger', 'dc comics', 'hell', 'facial scar', 'death']
# ['nan']
# ['dance', 'stomp']
# ['bollywood']
# ['vampire', 'high school', 'prom', 'spoof', 'horror spoof']
# ['corruption', 'capitalism', 'globalization', 'bank', 'banker']
# ['assassin']
# ['angel', 'faith', 'diner', 'apocalypse', 'demon']
# ['remake', 'remake of french film']
# ['nan']
# ['brother sister relationship', 'marriage', 'bully', 'duringcreditsstinger']
# ['nanny', 'fantasy', 'children', 'aftercreditsstinger', 'duringcreditsstinger']
# ['female nudity', 'one-night stand', 'time travel', 'time machine', 'incest overtones']
# ['experiment with human beings', 'psychological thriller', 'experiment gone wrong']
# ['vampire', 'child vampire', 'remake', 'bully', 'young boy']
# ['shyness', 'based on novel', 'unrequited love', 'neighbor', 'family relationships']
# ['owl']
# ['heist']
# ['musical', 'los angeles', 'burlesque', 'burlesque dancer']
# ['stock price', 'corporate', 'carpenter', 'job hunting']
# ['male nudity', 'sex', 'san francisco', 'waitress', 'newspaper']
# ['nan']
# ['woman director']
# ['ouija board', 'haunting', 'demonic possession', 'found footage', 'duringcreditsstinger']
# ['soul', 'based on novel', 'sadness', 'forgiveness', 'dystopia']
# ['martial arts', 'vigilante', 'joker', 'superhero', 'based on comic book']
# ['prostitute', 'sweden', 'suspense', 'priest', 'very little dialogue']
# ['nan']
# ['new york', 'money laundering', 'daughter', 'police', 'undercover cop']
# ['hostage', 'vomit', 'car crash', 'photograph', 'pistol']
# ['monster', 'pyramid', 'radio', 'dystopia', 'infection']
# ['france', 'father-son relationship', 'spain', 'pilgrimage', 'road trip']
# ['baby', 'godmother', 'death of a friend', 'romantic comedy', 'parenthood']
# ['roman empire', 'ancient rome', 'ancient world', 'britain', 'behind enemy lines']
# ['gay', 'loss of mother', 'secret', 'coming out', 'loss of father']
# ['nan']
# ['unsimulated sex', 'crying', 'brutality']
# ['soul', 'faith', 'supernatural', 'murder', 'fear']
# ['prison', 'fire', 'manipulation', 'seduction', 'vegetarian']
# ['based on novel', 'coming of age', 'young boy', 'middle school', 'popularity']
# ['rape', 'fondling', 'revenge', 'writer', 'strangulation']
# ['yacht', 'movie in movie', 'scuba diving', 'piranha', 'spring break']
# ['work ethic', 'tv morning show', 'tv reporter']
# ['prison', 'brother sister relationship', 'law school']
# ['nan']
# ['exorcism', 'fraud', 'evil spirit', 'human sacrifice', 'mockumentary']
# ['fairy', 'hockey', 'tooth fairy', 'tooth', 'duringcreditsstinger']
# ['journalist', 'based on novel', 'undercover', 'dating', 'co-worker']
# ['cia', 'nuclear scientist', 'iraq', 'politician', 'duringcreditsstinger']
# ['nurse', 'mental disease', 'orderly', 'farm', 'electric shock']
# ['illuminati', 'marvel comic', 'superhero', 'based on comic book', 'space opera']
# ['isolation', 'coffin', 'race against time', 'buried alive', 'survival']
# ['mouse', 'idiot', 'mind control', 'taxidermy', 'aftercreditsstinger']
# ['new york', 'rome', 'romantic comedy', 'romance', 'spell']
# ['bodyguard']
# ['love', 'hollywood', 'unemployed']
# ['waitress', 'sperm', 'underwear', 'lesbian', 'dinner']
# ['nan']
# ['missile', 'light', 'transformation', 'low budget', 'alien']
# ['beach', 'mossad', 'secret agent', 'insane asylum', 'lye']
# ['number in title', 'digit in title', 'sea turtle', '3d']
# ['independent film']
# ['suspense', 'psychological thriller', 'violence', 'building', 'tv news']
# ['father', 'court', 'bail', 'drug trade', 'girl']
# ['beach', 'jazz', 'seduction', 'musical', 'song']
# ['independent film', 'money']
# ['torture', 'aftercreditsstinger', 'duringcreditsstinger']
# ['summer camp', 'camp', 'singing', 'singing competition']
# ['aftercreditsstinger', 'duringcreditsstinger']
# ['sister sister relationship', 'mother daughter relationship', 'aunt niece relationship', 'father daughter relationship', 'duringcreditsstinger']
# ['father-son relationship', 'victorian england', 'rural setting', 'werewolf']
# ['personal assistant']
# ['love triangle', 'baseball', 'athlete', 'aftercreditsstinger']
# ['pain', 'stunt', 'stuntman', 'stupidity', 'comedy']
# ['nan']
# ['prophecy', 'camelot', 'reincarnation', 'high school', 'king arthur']
# ['brazilian', 'career', 'legend', 'champion', 'sport']
# ['drug traffic', 'nudity', 'exploitation', 'revenge', 'gun violence']
# ['exploding building', 'duringcreditsstinger']
# ['nan']
# ['duringcreditsstinger']
# ['confidence', 'insecurity', 'airport security', 'rating', 'hockey game']
# ['inquisition', 'monk', 'witch', 'village', 'battlefield']
# ['difficult childhood', 'patriarch', 'childhood trauma', 'dysfunctional marriage']
# ['vomit', 'food poisoning', 'apostrophe in title', 'show within a show']
# ['sheriff', 'crime fighter']
# ['loss of sister', 'paparazzi', 'shot in the head', 'racist gangster', 'murdered sister']
# ['nan']
# ['nan']
# ['soul', 'serial killer', 'slasher', 'teenager']
# ['martial arts', 'dystopia', 'based on video game', 'martial arts tournament']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-cf0d57cbfca0> in <module>
#       1 a = []
#       2 for i in range(len(kword)):
# ----> 3     lis = str(kword[i]).split('|')
#       4     print(lis)
#       5     for j in range(len(lis)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2090

# %%
# count each occurences of keywords
def occur_count(k):
    a = []
    for i in range(len(k)):
        lis = str(k[i]).split('|')
        #print(lis)
        for j in range(len(lis)):
            a.append(lis[j])
    return a

# %%
# the function for the calculation of occurences
def top_occurs(l):
    
    
    keywords, occurrences = np.unique(l, return_counts = True)

    # save to dataframe for conveneince use 
    data  = {'occurrences': occurrences, 'names': keywords}
    df_keywords = pd.DataFrame(data)

    top10_occurrences = df_keywords.sort_values('occurrences', ascending = False)
    return top10_occurrences

# %%
# count each occurences of keywords
occurs = occur_count(kword)
# top10 keywords 
top10_kwords = top_occurs(occurs)[1:10]

#set the figsize 
plt.figure(figsize=(8,6))
# rotate x axes values 
plt.xticks(rotation=90)
#set the title
plt.title('Top 10 most used keywords')
# x, y labels
plt.ylabel('Numbero of keywords')
plt.xlabel('Keywords')
#plot as a horizontal bar graph
plt.bar(top10_kwords['names'], top10_kwords['occurrences']);
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-c0f4d37c06ba> in <module>
#       1 # count each occurences of keywords
# ----> 2 occurs = occur_count(kword)
#       3 # top10 keywords
#       4 top10_kwords = top_occurs(occurs)[1:10]
#       5
#
# <ipython-input-15-bade4af3bb5b> in occur_count(k)
#       3     a = []
#       4     for i in range(len(k)):
# ----> 5         lis = str(k[i]).split('|')
#       6         #print(lis)
#       7         for j in range(len(lis)):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2090

# %% [markdown]
# Short conclusion: The most common keyword was 'woman director' with occurance more than 400. Overall, the occurance of the keywords for top 10 keywords was over than 150.

# %% [markdown]
# ### Research Question 3:  What genres with the highest release?

# %% [markdown]
# Similarly to question 2 we can easily calculate popular genres by its occurences

# %%
#take genres from the data 
genres = df['genres']

#count occurences of each genres
genres_occurs = occur_count(genres)
#top10_genres
top10_genres = top_occurs(genres_occurs)[1:10]

#set the figsize 
plt.figure(figsize=(8,6))
#plot as a horizontal bar graph
plt.barh(top10_genres['names'], top10_genres['occurrences']);
#set the title
plt.title('Genres with the highest release')
#labels
plt.ylabel('Genres')
plt.xlabel('Number of Movies')
plt.show()

# %% [markdown]
# Short conclusion: From the chart it is easy to explore that release of 'drama' movies are dominated over the other genres such as 'crime', 'adventure', 'family' by almost two time more releases. Second hihgest released genre was 'comedy', almost 4000 releases.

# %% [markdown]
# ### Research Question 4: What are the most voted movies?

# %%
#the title of movies and votes for movies are extracted to new file 
votes = df[['original_title', 'vote_count']]

#sort top10 votes by the title of movie 
top10_votes = votes.sort_values('vote_count', ascending = False)[1:10]

#plotting top 10 movies with the number of votes
#define the figsize
plt.figure(figsize = (8, 6))
#define the title oof the chart
plt.title('Most voted movies')
#labels
plt.xlabel('The number of Votes')
plt.ylabel('Movies')
#plot as a horizontal bar graph
plt.barh(top10_votes['original_title'], top10_votes['vote_count'])
plt.show()

# %% [markdown]
# Short conclusion: The figure shows that people mostly voted for 'The Avengers', 'Avater' and 'The Dark Knight', with the number of release higher than 8000 votes. Overall, the votes for movies was higher than averagely 6000 votes for top 10 movies.

# %% [markdown]
# ### Research Question 5: Relationship between popularity vs budget ? poularity vs revenue?

# %% [markdown]
# #### 5.1 Popularity vs Budget

# %%
# extract budget and popularity 
pop_budget = df[['budget', 'popularity']]

# calculation of the correlation between budget and populariyt
pop_budget_corr = pop_budget.corr(method = 'pearson')
corr = pop_budget_corr.loc['budget', 'popularity']

print('The correlation between popularity and budget is {}'.format(corr))

# plot the popularit vs budget 
ax = sns.regplot(x=pop_budget['popularity'], y=pop_budget['budget'],color='c')
#set the title and labels of the figure
ax.set_title("Popularity Vs Budget",fontsize=13)
ax.set_xlabel("Revenue",fontsize=12)
ax.set_ylabel("Budget",fontsize=12)
#set the figure size
sns.set(rc={'figure.figsize':(6,4)})
sns.set_style("whitegrid")

#### 5.3 Popularity vs Revenue

# %% [markdown]
# Short conclusion: From correlation analysis it easy to assume that popularity and budget are not correlated strongly by showing averge amount, almost 54%. Overall, we can conclude that popular movies does not need to be funded heavily, which means lower budget movies can also achieve higher popularity.

# %% [markdown]
# #### 5.3 Popularity vs Revenue

# %%
#how does profit change according to their budget.
#make a scatter plot using 'regplot' between 'popularity' and 'revenue'.
ax = sns.regplot(x=df['popularity'], y=df['revenue'],color='c')

#setup the title and the labels of the plot.
ax.set_title("Popularity Vs Revenue",fontsize=13)
#ax.set_xlabel("Profit",fontsize=12)
ax.set_ylabel("Revenue",fontsize=12)
ax.set_xlabel("Popularity", fontsize=12)

#setup the figure size and style sheet of the plot.
sns.set(rc={'figure.figsize':(6,4)})
sns.set_style("whitegrid")

data_corr = df.corr()
#print the correction between them,which was stored in 'data_corr'.
print("Correlation Between Popularity And Revenue : ",data_corr.loc['popularity','revenue'])

# %% [markdown]
# Short conclusion: Our coorelation analysis among popularity and revenue show positive value, that is 66%. Thus we can assume the more popular more revenue.

# %%
#how does popularity change according to their budget.
#make a scatter plot using 'regplot' between 'popularity' and 'budget'.
ax = sns.regplot(x=df['budget'], y=df['revenue'],color='c')

#setup the title and the labels of the plot.
ax.set_title("Budget Vs Revenue",fontsize=13)
ax.set_ylabel("Revenue",fontsize=12)
ax.set_xlabel("Budget", fontsize=12)
#setup the figure size and style sheet of the plot.
sns.set(rc={'figure.figsize':(6,4)})
sns.set_style("whitegrid")

data_corr = df.corr()
#print the correction between them,which was stored in 'data_corr'.
print("Correlation Between Budget And Revenue : ",data_corr.loc['budget','revenue'])

# %% [markdown]
# Short conclusion: The correlation value between budget and revenue was around 73%. which means there is strong relationship between these two variables. This resul can be considered when the deeper analysis are applied to get higher profit.

# %% [markdown]
# ### Research Question 6: What is a Budget and revenue change per year?

# %% [markdown]
# #### 1. Budget change per year

# %%
# calculate the budget 
budget_year = df.groupby('release_year')['budget'].mean()

sns.set(rc={'figure.figsize':(10,5)})

plt.xticks(np.arange(1960, 2016, 5))

plt.title('Budget change per-year')
plt.ylabel('Budget ($)')
plt.xlabel('Years')
plt.plot(budget_year);

sns.set_style("whitegrid")

# %% [markdown]
# Short conclusion: The line graph shows that the budget between 1995 and 2000 years experienced dramatic increase over the 2.5 billion dollar. After 20th budget start to falling down with high decrease, in 2015, the budget amount was below than 1.5 billion.

# %% [markdown]
# #### 2. Revenue change per year

# %%
budget_year = df.groupby('release_year')['revenue'].mean()

sns.set(rc={'figure.figsize':(10,5)})

plt.xticks(np.arange(1960, 2016, 5))
plt.title('Revenue change per year')
plt.ylabel('Revenue ($)')
plt.xlabel('Years')

plt.plot(budget_year);

# %% [markdown]
# Short conclusion: It is clear that the revenue is increased per-year with little fluctutation. It is needed to be mentioned that the revenue for 2000 was the highest with the hihger than five billion dollar, in ocompared to 2015 which was around four billion

# %% [markdown]
# ### Research Question 7: How the number of released movies are changed per-year?

# %%
data = df.groupby('release_year').count()['id']

sns.set(rc={'figure.figsize':(10,5)})

plt.xticks(np.arange(1960, 2016, 5))

plt.ylabel('Revenue ($)')
plt.xlabel('Years')

plt.plot(data);

# %% [markdown]
# Short conclusion: From the graph it is obvious to see that number of released movies per year are increased rapidly after 20th, while it was performing slow pace increase fomr 1960 to 2000. Overall, the trends for releases of movies are increasing.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# > **Results:**
# 1. Most searched keyword was "Woman director".
# 2. Drame, Comedy, Thriller and Action are four most-made genres.
# 3. Top 3 most voted movies: "The Avengers", "Avatar" and "The Dark Knight"
# 4. There is positive corellation between Popularity and Budget almost 0.66%
# 5. The relationship between Budget and Revenue is very strong.
# 6. The budget for movies are decreased after 20'th
# 7. The revenue from movies are start to decrease after 20th with fluctuations each year
# 8. The number of released movies per-year is performed dramatic increase between 2005 and 2015
# 9. Movies with higher budgets have shown a corresponding increase in the revenues.
#
# > **Limitations:**
# 1. The dataset columns include many null values which makes the analysis much harder, when other variables are related to these columns.
# 2. Some columns contain many values that are separated with "|" such as genres, cast. Which increase the time to process.
# 3. There is not any informaion in the dataset about currency information. For example, in the analysis of revenue, and budget, there is not currency information is given. Thus I assumed it as a dollar to make more understandable.
